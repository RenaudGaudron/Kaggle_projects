# %%
# Importing the relevant Python libraries

# %reset -f

# General libraries
import numpy as np
import pandas as pd
import scipy
import os
import cv2
from PIL import Image

# ML libraries
from sklearn import metrics
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score
from fastai.vision.all import *
import optuna

# Changing a few default options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
np.set_printoptions(threshold = 1e6)

# %%
# Loading the RESNET34 model using Fastai and using transfer training to train a CNN to find out if there is a cat in a picture or not.

# # Kaggle directory
#path_model= os.path.abspath("cat_model.pkl")

# Local directory
path_model= os.path.abspath("cat_model.pkl")

def is_cat(x): return x[0].isupper()

try: # Loading the pre-trained model if it exists
    learn = load_learner(path_model)
except:  # If the pre-trained model does not exist, we need to train it.
    path = untar_data(URLs.PETS)/'images' # Downloading and extracting the pictures used to do the transfer training

    dls = ImageDataLoaders.from_name_func(path, get_image_files(path), valid_pct=0.2, seed=42, label_func=is_cat, item_tfms=Resize(224)) # Loading and pre-processing step - Fastai

    learn = cnn_learner(dls, resnet34, metrics=error_rate) # Instantiating the model
    learn.fine_tune(1) # Training the model
    learn.export(path_model) # Exporting the model to a file

# %%
# Function used to extract features from a given picture

def image_features(img,filename):
    list_feat = dict() # Initialising a new dictionary
    list_feat['Id']=filename.replace(".jpg", "") # The Id is the name of the file
    list_feat['img_x']=img.shape[0] # Dimension of the image - x axis
    list_feat['img_y']=img.shape[1] # Dimension of the image - y axis
    
    with learn.no_bar(), learn.no_logging():
        _,_,probs = learn.predict(img)  # Determining the probability that there is a cat in the picture
        list_feat['prob_cat']=probs[1].numpy() # Adding it to the dictionary
                                   
    return list_feat

# %%
# Extracting features from all pictures

try: # If the data has already been processed and stored in two separate files
    data_train=pd.read_csv('data_train.csv')
    data_test=pd.read_csv('data_test.csv')
except: # If the data has not been processed yet
    
    # # Kaggle directory
    # dir_gen='/kaggle/input/petfinder-pawpularity-score'
    # dir_train='/kaggle/input/petfinder-pawpularity-score/train'
    # dir_test='/kaggle/input/petfinder-pawpularity-score/test'

    # Local directory
    dir_gen='../data'
    dir_train='../data\\train'
    dir_test='../data\\test'

    data_train=pd.read_csv(os.path.join(dir_gen, 'train.csv')) # Loading the initial data as provided by Kaggle
    data_test=pd.read_csv(os.path.join(dir_gen, 'test.csv')) # Loading the initial data as provided by Kaggle

    image_data_train=[] 
    image_data_test=[]

    for dirname, _, filenames in os.walk(dir_gen): # Listing all files and directories in dir_gen
        for filename in filenames: # Looping over the filenames
            if filename[-3:]=='jpg': # Checking whether the file is a jpg image
                img = cv2.imread(os.path.join(dirname, filename)) # Loading the image
                if dirname==dir_train: # If the image is in the training set
                    image_data_train.append(image_features(img,filename)) # Computing the features and appending to the list
                elif dirname==dir_test: # If the image is in the testing set
                    image_data_test.append(image_features(img,filename)) # Computing the features and appending to the list

    df_add_train = pd.DataFrame(image_data_train) # Converting the list to a dataframe
    data_train = pd.merge(data_train, df_add_train, how="inner", left_on='Id', right_on='Id') # Merging the two dataframes
    data_train.set_index('Id', inplace=True) # Setting the index

    df_add_test = pd.DataFrame(image_data_test) # Converting the list to a dataframe
    data_test = pd.merge(data_test, df_add_test, how="inner", left_on='Id', right_on='Id') # Merging the two dataframes
    data_test.set_index('Id', inplace=True) # Setting the index

# %%
data_train.head(15) # Checking the first 15 rows of the dataframe corresponding to the training set
# Out:
#                                   Id  Subject Focus  Eyes  Face  Near  Action  \
# 0   0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 1   0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 2   0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 3   0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 4   001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
# 5   001dd4f6fafb890610b1635f967ea081              0     0     1     0       0
# 6   0023b8a3abc93c712edd6120867deb53              0     1     1     1       0
# 7   0031d6a9ef7340f898c3e05f92c7bb04              0     1     1     0       0
# 8   0042bc5bada6d1cf8951f8f9f0d399fa              0     1     1     1       0
# 9   0049cb81313c94fa007286e9039af910              0     1     1     1       0
# 10  005017716086b8d5e118dd9fe26459b1              0     1     1     1       0
# 11  00524dbf2637a80cbc80f70d3ff59616              0     1     1     1       0
# 12  00630b1262efe301cb15a3b2022ba744              0     1     1     1       0
# 13  006483b96ca9c09b7afed3e3d3af539d              0     1     1     1       0
# 14  00655425c10d4c082dd7eeb97fa4fb17              0     1     0     0       0
#
#     Accessory  Group  Collage  Human  Occlusion  Info  Blur  Pawpularity  \
# 0           0      1        0      0          0     0     0           63
# 1           0      0        0      0          0     0     0           42
# 2           0      0        0      1          1     0     0           28
# 3           0      0        0      0          0     0     0           15
# 4           0      1        0      0          0     0     0           72
# 5           0      0        0      0          0     0     1           74
# 6           0      0        0      1          1     0     0           22
# 7           0      1        1      0          0     1     0           35
# 8           0      0        0      0          0     0     0           53
# 9           0      0        0      0          0     0     0           21
# 10          0      0        0      0          0     0     0           28
# 11          0      0        0      0          0     0     0            2
# 12          0      0        0      0          0     0     0           18
# 13          0      0        0      1          1     0     0           41
# 14          1      0        0      0          0     0     0           13
#
#     img_x  img_y      prob_cat
# 0     720    405  4.942153e-07
# 1     774   1032  1.000000e+00
# 2     960    720  8.513125e-04
# 3     720    405  1.401318e-06
# 4     960    540  1.987255e-03
# 5     960    540  5.182422e-09
# 6     960    720  1.946210e-06
# 7    1280   1280  2.425766e-02
# 8     960    720  1.000000e+00
# 9     847   1279  1.000000e+00
# 10   1280   1280  1.000000e+00
# 11    720    405  2.589517e-07
# 12    960    540  9.999222e-01
# 13    960    720  9.503042e-07
# 14    638    581  1.000000e+00

# %%
data_test.head(15) # Checking the first 15 rows of the dataframe corresponding to the testing set
# Out:
#                                  Id  Subject Focus  Eyes  Face  Near  Action  \
# 0  4128bae22183829d2b5fea10effdb0c3              1     0     1     0       0
# 1  43a2262d7738e3d420d453815151079e              0     1     0     0       0
# 2  4e429cead1848a298432a0acad014c9d              0     0     0     1       0
# 3  80bc3ccafcc51b66303c2c263aa38486              1     0     1     0       0
# 4  8f49844c382931444e68dffbe20228f4              1     1     1     0       1
# 5  b03f7041962238a7c9d6537e22f9b017              0     0     1     1       1
# 6  c978013571258ed6d4637f6e8cc9d6a3              1     0     0     0       1
# 7  e0de453c1bffc20c22b072b34b54e50f              1     0     1     0       0
#
#    Accessory  Group  Collage  Human  Occlusion  Info  Blur  img_x  img_y  \
# 0          1      1        0      0          1     0     1    128    128
# 1          0      1        1      0          0     0     0    128    128
# 2          1      1        1      0          1     1     1    128    128
# 3          0      0        0      0          0     1     0    128    128
# 4          1      0        1      0          1     1     0    128    128
# 5          1      1        1      1          0     1     0    128    128
# 6          1      0        1      0          1     1     1    128    128
# 7          0      0        0      1          0     0     1    128    128
#
#    prob_cat
# 0  0.000891
# 1  0.000472
# 2  0.000619
# 3  0.000552
# 4  0.000462
# 5  0.001552
# 6  0.001804
# 7  0.000470

# %%
data_train.describe() # Generating descriptive statistics about the training set
# Out:
#        Subject Focus         Eyes         Face         Near       Action  \
# count    9912.000000  9912.000000  9912.000000  9912.000000  9912.000000
# mean        0.027643     0.772599     0.903955     0.861582     0.009988
# std         0.163957     0.419175     0.294668     0.345356     0.099444
# min         0.000000     0.000000     0.000000     0.000000     0.000000
# 25%         0.000000     1.000000     1.000000     1.000000     0.000000
# 50%         0.000000     1.000000     1.000000     1.000000     0.000000
# 75%         0.000000     1.000000     1.000000     1.000000     0.000000
# max         1.000000     1.000000     1.000000     1.000000     1.000000
#
#          Accessory        Group      Collage        Human    Occlusion  \
# count  9912.000000  9912.000000  9912.000000  9912.000000  9912.000000
# mean      0.067797     0.129338     0.049637     0.166263     0.172014
# std       0.251409     0.335591     0.217204     0.372335     0.377411
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#               Info         Blur  Pawpularity        img_x        img_y  \
# count  9912.000000  9912.000000  9912.000000  9912.000000  9912.000000
# mean      0.061239     0.070420    38.039044   904.284302   804.426251
# std       0.239780     0.255866    20.591990   156.905980   270.211921
# min       0.000000     0.000000     1.000000   113.000000    90.000000
# 25%       0.000000     0.000000    25.000000   908.750000   675.000000
# 50%       0.000000     0.000000    33.000000   960.000000   720.000000
# 75%       0.000000     0.000000    46.000000   960.000000   960.000000
# max       1.000000     1.000000   100.000000  1280.000000  1280.000000
#
#            prob_cat
# count  9.912000e+03
# mean   4.980068e-01
# std    4.848534e-01
# min    3.600814e-12
# 25%    1.229047e-05
# 50%    4.742918e-01
# 75%    1.000000e+00
# max    1.000000e+00

# %%
# Checking if there is missing data in the training set
data_train_NaN=data_train[data_train.isnull().any(axis=1)]
data_train_NaN.head()
# Conclusion: there is no missing data in the training set
# Out:
# Empty DataFrame
# Columns: [Id, Subject Focus, Eyes, Face, Near, Action, Accessory, Group, Collage, Human, Occlusion, Info, Blur, Pawpularity, img_x, img_y, prob_cat]
# Index: []

# %%
# Checking if there is missing data in the testing set
data_test_NaN=data_test[data_test.isnull().any(axis=1)]
data_test_NaN.head()
# Conclusion: there is no missing data in the testing set
# Out:
# Empty DataFrame
# Columns: [Id, Subject Focus, Eyes, Face, Near, Action, Accessory, Group, Collage, Human, Occlusion, Info, Blur, img_x, img_y, prob_cat]
# Index: []

# %%
Features=list(set(data_train.columns.values)-{'Pawpularity', 'Id'}) # Listing all features (i.e. removing the Id and output vectors)
Best_Feat=[]

for feature in sorted(Features): # Looping over all features
    try:
        pearson_coef, p_value = scipy.stats.pearsonr(data_train['Pawpularity'], data_train[feature]) # Computing the correlation coefficient and p-value between that feature and the Pawpularity score
        print(feature,"- Pawpularity: the Pearson correlation coefficient is", round(pearson_coef,3), " with a P-value of", format(p_value,".3E")) 
        if abs(pearson_coef)>0.00 and p_value<.05: # Checking if the correlation coefficient is statistically significant
            Best_Feat.append(feature) # Appending the feature to the list of best features
    except:
        pass

print('\nThe best features are:',Best_Feat) # Printing the best features
# Out:
# Accessory - Pawpularity: the Pearson correlation coefficient is 0.013  with a P-value of 1.859E-01
# Action - Pawpularity: the Pearson correlation coefficient is -0.001  with a P-value of 8.913E-01
# Blur - Pawpularity: the Pearson correlation coefficient is -0.024  with a P-value of 1.909E-02
# Collage - Pawpularity: the Pearson correlation coefficient is 0.002  with a P-value of 8.631E-01
# Eyes - Pawpularity: the Pearson correlation coefficient is -0.007  with a P-value of 5.057E-01
# Face - Pawpularity: the Pearson correlation coefficient is 0.008  with a P-value of 4.248E-01
# Group - Pawpularity: the Pearson correlation coefficient is 0.016  with a P-value of 1.011E-01
# Human - Pawpularity: the Pearson correlation coefficient is 0.004  with a P-value of 6.917E-01
# Info - Pawpularity: the Pearson correlation coefficient is -0.005  with a P-value of 6.374E-01
# Near - Pawpularity: the Pearson correlation coefficient is 0.001  with a P-value of 9.206E-01
# Occlusion - Pawpularity: the Pearson correlation coefficient is 0.002  with a P-value of 8.438E-01
# Subject Focus - Pawpularity: the Pearson correlation coefficient is -0.01  with a P-value of 3.267E-01
# img_x - Pawpularity: the Pearson correlation coefficient is -0.023  with a P-value of 2.107E-02
# img_y - Pawpularity: the Pearson correlation coefficient is -0.022  with a P-value of 3.191E-02
# prob_cat - Pawpularity: the Pearson correlation coefficient is -0.165  with a P-value of 1.826E-61
#
# The best features are: ['Blur', 'img_x', 'img_y', 'prob_cat']

# %%
X_norm=data_train[Best_Feat].append(data_test[Best_Feat]) # Appending the training and testing sets

X_norm=preprocessing.StandardScaler(with_mean=True, with_std=True).fit_transform(X_norm) # Normalising the features

# Defining the feature matrices and output vector
Y=data_train['Pawpularity'].values
X=X_norm[0:len(Y),:]  
X_test=X_norm[len(Y):len(X_norm),:]

# Checking the shape of the resulting matrices/vectors
print('Shape of Y:', Y.shape)
print('Shape of X:', X.shape)
print('Shape of X_test:',X_test.shape)
# Out:
# Shape of Y: (9912,)
# Shape of X: (9912, 4)
# Shape of X_test: (8, 4)

# %%
# Training the Gradient Boosting algorithm and optimising the hyperparameters using Optuna

clf = GradientBoostingRegressor(loss='squared_error', learning_rate=0.05, random_state=2) # Gradient Boosting Regressor

# Listing the hyperparameters to optimise along with the corresponding minimum and maximum admissible values and the type of distribution
param_distributions = {
    "ccp_alpha": optuna.distributions.UniformDistribution(0, 1e-5),
    "subsample": optuna.distributions.UniformDistribution(0.5, 1),
    "n_estimators": optuna.distributions.IntUniformDistribution(1, 600),  
    "max_depth": optuna.distributions.IntUniformDistribution(1, 5),
    #"min_samples_split": optuna.distributions.IntUniformDistribution(2, 10),
    #"min_samples_leaf": optuna.distributions.IntUniformDistribution(1, 5),
}

# Optuna is used to find the optimal hyperparameters
optuna_search = optuna.integration.OptunaSearchCV(
    clf, param_distributions, n_trials=100, verbose=2, n_jobs=-1, cv=5, scoring='neg_root_mean_squared_error'
)

optuna_search.fit(X, Y)

print("Best trial:")
trial = optuna_search.study_.best_trial

print("  Value: ", -trial.value)
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
    
pred_GB=optuna_search.predict(X) # Predicting the output using the training set
acc_training_GB=metrics.mean_squared_error(Y,pred_GB, squared=False) # Computing the error using the training set

print('\nRMSE - Training set:',acc_training_GB)
print('Mean RMSE - CV set:',-trial.value)
# Out:
# C:\Users\Renaud\AppData\Local\Temp/ipykernel_10644/3239231340.py:16: ExperimentalWarning: OptunaSearchCV is experimental (supported from v0.17.0). The interface can change in the future.
#   optuna_search = optuna.integration.OptunaSearchCV(
# [I 2022-01-13 11:09:28,877] A new study created in memory with name: no-name-17161d5d-6253-41ad-a083-49b85e2e06ee
# [I 2022-01-13 11:09:28,877] Searching the best hyperparameters using 9912 samples...
# D:\Software\Anaconda\envs\ML_env\lib\site-packages\optuna\study\study.py:393: FutureWarning: `n_jobs` argument has been deprecated in v2.7.0. This feature will be removed in v4.0.0. See https://github.com/optuna/optuna/releases/tag/v2.7.0.
#   warnings.warn(
# [I 2022-01-13 11:09:30,768] Trial 0 finished with value: -20.290465691530255 and parameters: {'ccp_alpha': 8.152829101606788e-06, 'subsample': 0.5358419530089343, 'n_estimators': 42, 'max_depth': 2}. Best is trial 0 with value: -20.290465691530255.
# [I 2022-01-13 11:09:30,939] Trial 1 finished with value: -20.286484407898772 and parameters: {'ccp_alpha': 3.689990210582204e-06, 'subsample': 0.9706147235989453, 'n_estimators': 43, 'max_depth': 2}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:09:33,977] Trial 7 finished with value: -20.290227312944204 and parameters: {'ccp_alpha': 4.883164857410489e-06, 'subsample': 0.9199173607822524, 'n_estimators': 113, 'max_depth': 2}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:09:34,757] Trial 5 finished with value: -20.309317434896748 and parameters: {'ccp_alpha': 1.2996918356553735e-06, 'subsample': 0.548301283670403, 'n_estimators': 124, 'max_depth': 3}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:09:37,847] Trial 9 finished with value: -20.354074516139196 and parameters: {'ccp_alpha': 6.906133384236318e-06, 'subsample': 0.9976246737056873, 'n_estimators': 98, 'max_depth': 5}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:09:38,253] Trial 2 finished with value: -20.4143200497055 and parameters: {'ccp_alpha': 6.616150459012367e-06, 'subsample': 0.9714998444170567, 'n_estimators': 130, 'max_depth': 5}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:09:45,699] Trial 11 finished with value: -20.29490825601283 and parameters: {'ccp_alpha': 2.098833208700568e-06, 'subsample': 0.7178407720726413, 'n_estimators': 277, 'max_depth': 1}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:09:46,748] Trial 10 finished with value: -20.29716811800464 and parameters: {'ccp_alpha': 4.536834218102177e-06, 'subsample': 0.5470609977526958, 'n_estimators': 341, 'max_depth': 1}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:09:48,087] Trial 15 finished with value: -20.302309582497003 and parameters: {'ccp_alpha': 8.413324071569785e-06, 'subsample': 0.7644639646467749, 'n_estimators': 26, 'max_depth': 2}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:09:48,948] Trial 4 finished with value: -20.328825026970264 and parameters: {'ccp_alpha': 6.508772685999301e-06, 'subsample': 0.9078941186872816, 'n_estimators': 416, 'max_depth': 2}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:09:51,619] Trial 12 finished with value: -20.32403012220207 and parameters: {'ccp_alpha': 5.582904131682296e-06, 'subsample': 0.536847766217112, 'n_estimators': 300, 'max_depth': 2}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:09:57,011] Trial 14 finished with value: -20.297875857777825 and parameters: {'ccp_alpha': 6.78044910065528e-06, 'subsample': 0.8496277152798386, 'n_estimators': 295, 'max_depth': 1}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:09:57,671] Trial 8 finished with value: -20.82443052527672 and parameters: {'ccp_alpha': 9.66017010950445e-06, 'subsample': 0.5808337294212288, 'n_estimators': 426, 'max_depth': 5}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:10:02,418] Trial 3 finished with value: -20.62933704359626 and parameters: {'ccp_alpha': 6.098549529041672e-06, 'subsample': 0.7807061024473877, 'n_estimators': 525, 'max_depth': 4}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:10:02,679] Trial 6 finished with value: -20.506181803434366 and parameters: {'ccp_alpha': 2.901237814676834e-06, 'subsample': 0.8903546185111957, 'n_estimators': 585, 'max_depth': 3}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:10:03,468] Trial 18 finished with value: -20.36242101739038 and parameters: {'ccp_alpha': 3.6188078379931465e-06, 'subsample': 0.8653149467405956, 'n_estimators': 205, 'max_depth': 3}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:10:04,298] Trial 13 finished with value: -20.847974083405095 and parameters: {'ccp_alpha': 1.5698253114098538e-06, 'subsample': 0.5608698240500454, 'n_estimators': 403, 'max_depth': 5}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:10:05,521] Trial 16 finished with value: -20.391387164126304 and parameters: {'ccp_alpha': 1.1580190803049185e-06, 'subsample': 0.6599051281024761, 'n_estimators': 330, 'max_depth': 3}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:10:11,786] Trial 21 finished with value: -20.342161904675347 and parameters: {'ccp_alpha': 3.882108758218619e-06, 'subsample': 0.9015163162856356, 'n_estimators': 191, 'max_depth': 3}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:10:12,278] Trial 22 finished with value: -20.346628393390567 and parameters: {'ccp_alpha': 4.053398331164611e-06, 'subsample': 0.9385600175480937, 'n_estimators': 201, 'max_depth': 3}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:10:12,476] Trial 27 finished with value: -20.50368587672422 and parameters: {'ccp_alpha': 2.862491634768943e-06, 'subsample': 0.8192604989899578, 'n_estimators': 3, 'max_depth': 4}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:10:12,700] Trial 26 finished with value: -20.348385510298318 and parameters: {'ccp_alpha': 4.881489299191018e-06, 'subsample': 0.9536765950873294, 'n_estimators': 15, 'max_depth': 4}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:10:13,220] Trial 23 finished with value: -20.391717575124268 and parameters: {'ccp_alpha': 2.530433578270578e-07, 'subsample': 0.9440956645954438, 'n_estimators': 176, 'max_depth': 4}. Best is trial 1 with value: -20.286484407898772.
# [I 2022-01-13 11:10:15,068] Trial 29 finished with value: -20.28207947250761 and parameters: {'ccp_alpha': 2.586387559026225e-07, 'subsample': 0.6275704419797994, 'n_estimators': 56, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:15,523] Trial 24 finished with value: -20.415371496332675 and parameters: {'ccp_alpha': 8.402641371748726e-08, 'subsample': 0.9445107489469762, 'n_estimators': 200, 'max_depth': 4}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:15,654] Trial 28 finished with value: -20.283264327478737 and parameters: {'ccp_alpha': 8.21812827678348e-06, 'subsample': 0.6297510017686931, 'n_estimators': 73, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:16,485] Trial 30 finished with value: -20.284749772003362 and parameters: {'ccp_alpha': 9.148760131807305e-06, 'subsample': 0.6432480813938756, 'n_estimators': 73, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:17,041] Trial 25 finished with value: -20.419934427294567 and parameters: {'ccp_alpha': 1.024253063143053e-07, 'subsample': 0.9447839064321921, 'n_estimators': 200, 'max_depth': 4}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:18,807] Trial 31 finished with value: -20.28365808597959 and parameters: {'ccp_alpha': 2.802076954112464e-06, 'subsample': 0.6310835475514783, 'n_estimators': 76, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:18,977] Trial 34 finished with value: -20.297175458612493 and parameters: {'ccp_alpha': 9.222542370784829e-06, 'subsample': 0.6267581035384082, 'n_estimators': 59, 'max_depth': 1}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:19,279] Trial 32 finished with value: -20.284818937128414 and parameters: {'ccp_alpha': 2.768660483863964e-06, 'subsample': 0.6318667159282019, 'n_estimators': 76, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:19,569] Trial 33 finished with value: -20.288754964943603 and parameters: {'ccp_alpha': 8.209408317606059e-06, 'subsample': 0.6187737035069567, 'n_estimators': 77, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:20,236] Trial 35 finished with value: -20.29335197256472 and parameters: {'ccp_alpha': 9.93426118158747e-06, 'subsample': 0.6246339886911305, 'n_estimators': 75, 'max_depth': 1}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:21,135] Trial 36 finished with value: -20.296550113085804 and parameters: {'ccp_alpha': 2.861627373337773e-06, 'subsample': 0.613346124100505, 'n_estimators': 52, 'max_depth': 1}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:22,952] Trial 17 finished with value: -20.652212505151752 and parameters: {'ccp_alpha': 2.9312460011965645e-06, 'subsample': 0.806673995952926, 'n_estimators': 547, 'max_depth': 4}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:25,361] Trial 37 finished with value: -20.2904684565132 and parameters: {'ccp_alpha': 7.409478112659819e-06, 'subsample': 0.6898537382420199, 'n_estimators': 153, 'max_depth': 1}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:26,538] Trial 39 finished with value: -20.289425219963242 and parameters: {'ccp_alpha': 9.042738676467491e-06, 'subsample': 0.6996940233627952, 'n_estimators': 135, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:27,096] Trial 38 finished with value: -20.29058172058584 and parameters: {'ccp_alpha': 8.370837912518683e-06, 'subsample': 0.6958957207502169, 'n_estimators': 155, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:27,496] Trial 19 finished with value: -20.50341457450446 and parameters: {'ccp_alpha': 3.255705665543775e-06, 'subsample': 0.8849659352986111, 'n_estimators': 537, 'max_depth': 3}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:27,631] Trial 40 finished with value: -20.290100627299175 and parameters: {'ccp_alpha': 7.774082685144485e-06, 'subsample': 0.7069103395511709, 'n_estimators': 142, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:28,657] Trial 41 finished with value: -20.29453271458446 and parameters: {'ccp_alpha': 7.567026509258295e-06, 'subsample': 0.5005595272904046, 'n_estimators': 147, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:30,841] Trial 20 finished with value: -20.524155259443706 and parameters: {'ccp_alpha': 3.44065178268809e-06, 'subsample': 0.8685518369894472, 'n_estimators': 586, 'max_depth': 3}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:31,205] Trial 42 finished with value: -20.291354589195986 and parameters: {'ccp_alpha': 7.56443229239593e-06, 'subsample': 0.6966758365798458, 'n_estimators': 148, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:33,688] Trial 48 finished with value: -20.28466647494121 and parameters: {'ccp_alpha': 5.733599985600456e-06, 'subsample': 0.658998647771148, 'n_estimators': 92, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:36,472] Trial 50 finished with value: -20.282722378192307 and parameters: {'ccp_alpha': 7.411161324955762e-07, 'subsample': 0.5846510603136907, 'n_estimators': 99, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:36,515] Trial 49 finished with value: -20.288277430492393 and parameters: {'ccp_alpha': 5.757211012306023e-06, 'subsample': 0.6550211905200388, 'n_estimators': 105, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:38,740] Trial 53 finished with value: -20.28833522473482 and parameters: {'ccp_alpha': 6.698949806517706e-07, 'subsample': 0.5780457648305481, 'n_estimators': 41, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:39,069] Trial 43 finished with value: -20.295536825095677 and parameters: {'ccp_alpha': 9.152988050219117e-06, 'subsample': 0.7030707869830337, 'n_estimators': 245, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:39,617] Trial 51 finished with value: -20.283299840662266 and parameters: {'ccp_alpha': 8.887220983327957e-06, 'subsample': 0.5876119920387055, 'n_estimators': 110, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:40,127] Trial 46 finished with value: -20.30558049412169 and parameters: {'ccp_alpha': 7.656885670958367e-06, 'subsample': 0.5027628740735354, 'n_estimators': 237, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:40,224] Trial 45 finished with value: -20.302492633986123 and parameters: {'ccp_alpha': 7.448497998828147e-06, 'subsample': 0.5870053987621138, 'n_estimators': 243, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:40,785] Trial 44 finished with value: -20.317193007353065 and parameters: {'ccp_alpha': 7.841779185902291e-06, 'subsample': 0.5122854444467309, 'n_estimators': 261, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:40,863] Trial 47 finished with value: -20.30612427508872 and parameters: {'ccp_alpha': 5.82410444055125e-06, 'subsample': 0.5853814376362746, 'n_estimators': 247, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:42,290] Trial 52 finished with value: -20.282938699687847 and parameters: {'ccp_alpha': 9.152106549363455e-07, 'subsample': 0.5875120520066123, 'n_estimators': 100, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:45,172] Trial 55 finished with value: -20.285950476486 and parameters: {'ccp_alpha': 2.048867630906884e-06, 'subsample': 0.5921072982584018, 'n_estimators': 106, 'max_depth': 2}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:45,541] Trial 56 finished with value: -20.287823138259487 and parameters: {'ccp_alpha': 1.9375978187073392e-06, 'subsample': 0.5912799577350233, 'n_estimators': 114, 'max_depth': 1}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:46,040] Trial 57 finished with value: -20.288655498620017 and parameters: {'ccp_alpha': 1.7666973720479818e-06, 'subsample': 0.5949412521686992, 'n_estimators': 112, 'max_depth': 1}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:46,104] Trial 58 finished with value: -20.288519403465493 and parameters: {'ccp_alpha': 1.9450912449026993e-06, 'subsample': 0.5950799143445112, 'n_estimators': 112, 'max_depth': 1}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:46,198] Trial 60 finished with value: -20.290427897302624 and parameters: {'ccp_alpha': 2.121804585374081e-06, 'subsample': 0.6000146470425489, 'n_estimators': 103, 'max_depth': 1}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:46,772] Trial 59 finished with value: -20.289661556364397 and parameters: {'ccp_alpha': 8.650366474998894e-07, 'subsample': 0.5993743127435301, 'n_estimators': 112, 'max_depth': 1}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:46,984] Trial 62 finished with value: -20.30598018048416 and parameters: {'ccp_alpha': 7.323386604970916e-07, 'subsample': 0.5592397447747641, 'n_estimators': 34, 'max_depth': 1}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:47,811] Trial 66 finished with value: -20.30308385941949 and parameters: {'ccp_alpha': 9.341722294462255e-07, 'subsample': 0.5640096245914203, 'n_estimators': 26, 'max_depth': 3}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:47,848] Trial 63 finished with value: -20.29142182500501 and parameters: {'ccp_alpha': 7.461876489492061e-07, 'subsample': 0.5592327790861649, 'n_estimators': 34, 'max_depth': 3}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:48,143] Trial 61 finished with value: -20.290825146055102 and parameters: {'ccp_alpha': 2.050610826395237e-06, 'subsample': 0.6044914218306464, 'n_estimators': 114, 'max_depth': 1}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:48,333] Trial 64 finished with value: -20.28980626875133 and parameters: {'ccp_alpha': 1.0953268692939156e-06, 'subsample': 0.5638844044707493, 'n_estimators': 34, 'max_depth': 3}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:48,499] Trial 65 finished with value: -20.291271526826144 and parameters: {'ccp_alpha': 1.0216018579858705e-06, 'subsample': 0.5603823779646482, 'n_estimators': 37, 'max_depth': 3}. Best is trial 29 with value: -20.28207947250761.
# [I 2022-01-13 11:10:49,476] Trial 67 finished with value: -20.278767010762547 and parameters: {'ccp_alpha': 5.690293143117928e-07, 'subsample': 0.6759573704682605, 'n_estimators': 41, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:10:49,597] Trial 74 finished with value: -20.55739607456143 and parameters: {'ccp_alpha': 1.5109079267443594e-06, 'subsample': 0.6740952417814169, 'n_estimators': 1, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:10:52,236] Trial 68 finished with value: -20.29635628241881 and parameters: {'ccp_alpha': 1.3397047253546863e-06, 'subsample': 0.6733504919218641, 'n_estimators': 86, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:10:52,634] Trial 70 finished with value: -20.286186106819724 and parameters: {'ccp_alpha': 1.256171978990719e-06, 'subsample': 0.6747726650217517, 'n_estimators': 87, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:10:52,776] Trial 75 finished with value: -20.285103233226152 and parameters: {'ccp_alpha': 5.444953145400866e-07, 'subsample': 0.6441771134292937, 'n_estimators': 58, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:10:52,977] Trial 71 finished with value: -20.285550356292482 and parameters: {'ccp_alpha': 1.3465535645773796e-06, 'subsample': 0.6686473996950613, 'n_estimators': 87, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:10:53,103] Trial 72 finished with value: -20.285260114434244 and parameters: {'ccp_alpha': 1.4049583707690696e-06, 'subsample': 0.67170127546314, 'n_estimators': 87, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:10:53,474] Trial 54 finished with value: -20.307874873061092 and parameters: {'ccp_alpha': 2.103532132525249e-06, 'subsample': 0.5952631096284575, 'n_estimators': 261, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:10:56,030] Trial 77 finished with value: -20.281029778729554 and parameters: {'ccp_alpha': 2.935104292176716e-07, 'subsample': 0.7423871671809646, 'n_estimators': 59, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:10:56,455] Trial 81 finished with value: -20.284271423227104 and parameters: {'ccp_alpha': 4.0934853556447914e-07, 'subsample': 0.531147745585835, 'n_estimators': 60, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:10:57,182] Trial 69 finished with value: -20.294667096858394 and parameters: {'ccp_alpha': 1.3852110367582776e-06, 'subsample': 0.6729684466236947, 'n_estimators': 172, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:10:57,206] Trial 83 finished with value: -20.36930421433943 and parameters: {'ccp_alpha': 8.73179773044288e-06, 'subsample': 0.7314329139463144, 'n_estimators': 13, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:10:57,890] Trial 73 finished with value: -20.292728312919305 and parameters: {'ccp_alpha': 1.4799492036625745e-06, 'subsample': 0.6771622561994085, 'n_estimators': 174, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:01,383] Trial 80 finished with value: -20.29659498380148 and parameters: {'ccp_alpha': 3.7018038679800363e-07, 'subsample': 0.5324065168510886, 'n_estimators': 164, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:01,499] Trial 86 finished with value: -20.280730155410268 and parameters: {'ccp_alpha': 2.93060289351891e-09, 'subsample': 0.7614532823815167, 'n_estimators': 61, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:02,214] Trial 79 finished with value: -20.296035984760987 and parameters: {'ccp_alpha': 3.5255724019458414e-07, 'subsample': 0.7342799108242921, 'n_estimators': 174, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:05,266] Trial 88 finished with value: -20.28432907883306 and parameters: {'ccp_alpha': 1.025363365470276e-08, 'subsample': 0.7785438126666474, 'n_estimators': 66, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:08,763] Trial 82 finished with value: -20.475891437880573 and parameters: {'ccp_alpha': 3.9903332480339686e-07, 'subsample': 0.7228577549244289, 'n_estimators': 175, 'max_depth': 5}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:08,837] Trial 90 finished with value: -20.320073312467194 and parameters: {'ccp_alpha': 6.448013788553224e-06, 'subsample': 0.7574050140255656, 'n_estimators': 50, 'max_depth': 5}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:09,252] Trial 89 finished with value: -20.315240550625354 and parameters: {'ccp_alpha': 5.983528849418924e-08, 'subsample': 0.6395502211930005, 'n_estimators': 133, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:13,840] Trial 76 finished with value: -20.35353722780143 and parameters: {'ccp_alpha': 4.277560010864696e-07, 'subsample': 0.6403879274942067, 'n_estimators': 452, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:14,710] Trial 78 finished with value: -20.352776775282273 and parameters: {'ccp_alpha': 6.478513843621748e-06, 'subsample': 0.5353263377204815, 'n_estimators': 464, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:14,774] Trial 84 finished with value: -20.325913975126575 and parameters: {'ccp_alpha': 4.330513922297801e-08, 'subsample': 0.7572298419455784, 'n_estimators': 364, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:15,004] Trial 85 finished with value: -20.331246410707628 and parameters: {'ccp_alpha': 2.49420529532771e-06, 'subsample': 0.7633609197459678, 'n_estimators': 372, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:15,281] Trial 94 finished with value: -20.31023007075281 and parameters: {'ccp_alpha': 6.555759871842728e-07, 'subsample': 0.8043280932814777, 'n_estimators': 21, 'max_depth': 4}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:18,131] Trial 98 finished with value: -20.287999084711238 and parameters: {'ccp_alpha': 5.206971186771214e-06, 'subsample': 0.6131012188358387, 'n_estimators': 68, 'max_depth': 2}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:20,514] Trial 99 finished with value: -20.283300445407278 and parameters: {'ccp_alpha': 2.612761830828187e-07, 'subsample': 0.5182355398012294, 'n_estimators': 51, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:21,354] Trial 96 finished with value: -20.3256554104062 and parameters: {'ccp_alpha': 4.430681642029688e-06, 'subsample': 0.8146840331534436, 'n_estimators': 126, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:21,525] Trial 97 finished with value: -20.31363219692318 and parameters: {'ccp_alpha': 9.568787715470948e-06, 'subsample': 0.803731013232942, 'n_estimators': 129, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:24,694] Trial 93 finished with value: -20.385772448093636 and parameters: {'ccp_alpha': 4.680862675648555e-06, 'subsample': 0.8176590452211732, 'n_estimators': 334, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:26,931] Trial 91 finished with value: -20.451632751723317 and parameters: {'ccp_alpha': 4.424785472151413e-06, 'subsample': 0.6397454705602761, 'n_estimators': 458, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:27,477] Trial 95 finished with value: -20.394269230851613 and parameters: {'ccp_alpha': 7.120636246351092e-06, 'subsample': 0.7904142818958573, 'n_estimators': 335, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:27,625] Trial 87 finished with value: -20.78453419232994 and parameters: {'ccp_alpha': 6.414194663596966e-08, 'subsample': 0.7655742183627465, 'n_estimators': 454, 'max_depth': 5}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:28,511] Trial 92 finished with value: -20.464707138283153 and parameters: {'ccp_alpha': 4.360393741547302e-06, 'subsample': 0.8146049707723269, 'n_estimators': 498, 'max_depth': 3}. Best is trial 67 with value: -20.278767010762547.
# [I 2022-01-13 11:11:28,512] Finished hyperparemeter search!
# [I 2022-01-13 11:11:28,514] Refitting the estimator using 9912 samples...
# [I 2022-01-13 11:11:28,690] Finished refitting! (elapsed time: 0.175 sec.)
# Best trial:
#   Value:  20.278767010762547
#   Params:
#     ccp_alpha: 5.690293143117928e-07
#     subsample: 0.6759573704682605
#     n_estimators: 41
#     max_depth: 3
#
# RMSE - Training set: 20.145144825137592
# Mean RMSE - CV set: 20.278767010762547

# %%
Y_test = optuna_search.predict(X_test) # Predicting the output

# Writing the results to a file
final_data=np.column_stack((data_test.index.astype(str), np.transpose(Y_test).astype(float)))
np.savetxt("submission.csv", final_data, delimiter=",", header='Id,Pawpularity', fmt='%s,%f', comments='')
